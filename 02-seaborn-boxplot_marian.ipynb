# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("http://51.91.120.89/extras/pokemon.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.groupby("Type 1")["Attack"].agg([pd.np.mean, pd.np.std])
# Out:
# <ipython-input-3-d584160e153a>:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   df.groupby("Type 1")["Attack"].agg([pd.np.mean, pd.np.std])
#                 mean        std
# Type 1
# Bug        70.971014  37.040904
# Dark       88.387097  25.774247
# Dragon    112.125000  33.742622
# Electric   69.090909  23.764169
# Fairy      61.529412  29.751298
# Fighting   96.777778  28.290163
# Fire       84.769231  28.769275
# Flying     78.750000  37.500000
# Ghost      73.781250  29.629687
# Grass      73.214286  25.380520
# Ground     95.750000  33.059087
# Ice        72.750000  27.289511
# Normal     73.469388  30.295862
# Poison     74.678571  19.630010
# Psychic    71.456140  42.309265
# Rock       92.863636  35.325458
# Steel      92.703704  30.388276
# Water      74.151786  28.377192

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=df, x="Attack", y="Type 1", orient="h", color="red", whis=1)
# Out:
# <AxesSubplot:xlabel='Attack', ylabel='Type 1'>

# %%
plt.figure(figsize=(20,7))
sns.boxplot(data=df, y="Attack", x="Type 1", orient="v", whis=1, hue="Legendary")
# Out:
# <AxesSubplot:xlabel='Type 1', ylabel='Attack'>
